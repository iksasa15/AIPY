# %% [markdown]
# # Project: Student Admission Dataset
#
# You are given a dataset about student applications. Your job is to **explore the data**, **decide what kind of machine learning problem this is**, **choose a suitable approach**, and **build a complete pipeline** from preprocessing to evaluation.
#
# | Column | Description |
# |--------|-------------|
# | `GPA` | Student grade point average |
# | `SAT` | SAT score |
# | `Extracurricular_Hours` | Weekly extracurricular hours |
# | `Attendance_Pct` | Attendance percentage |
# | `Admitted` | Application outcome |
#
# **Dataset path:** `../Datasets/student_admission.csv`
#
# | Phase | Topic |
# |-------|-------|
# | Phase 0 | Setup — Install & Imports |
# | Phase 1 | Data Pre-processing — Load → Cleaning → Encoding → Prepare for Modeling |
# | Phase 2 | Modeling — Train → Predict → Visualize → Evaluate |
#
# > **Instructions:** Complete each empty code cell below. **Run all** before submission.

# %% [markdown]
# ## Phase 0 — Step 1: Install Libraries
#
# **Requirements:**
# - Install the libraries you need for data analysis and modeling
# - Use `-q` to hide installation output if using pip

# %%
# Write your code here

# %% [markdown]
# ## Phase 0 — Step 2: Import Libraries
#
# **Requirements:**
# - Import the libraries you plan to use
# - Set sensible defaults for plots (figure size, theme, random seed)
# - Print a confirmation message when imports are ready

# %%
# Write your code here

# %% [markdown]
# ---
# # Phase 1: Data Pre-processing
#
# Explore and prepare the data before modeling.

# %% [markdown]
# ## Phase 1 — Step 1: Load and Explore Data
#
# **Requirements:**
# - Load `../Datasets/student_admission.csv`
# - Display: `head()`, `info()`, `describe()`, `shape`
# - Explore each column — especially `Admitted` — and **write a short conclusion** (print or markdown) about what type of ML problem this appears to be

# %%
# Write your code here

# %% [markdown]
# ## Phase 1 — Step 2: Data Cleaning (Missing Values)
#
# **Requirements:**
# - Check missing values per column
# - Remove duplicate rows if any
# - Handle missing values appropriately for numeric columns **if needed**

# %%
# Write your code here

# %% [markdown]
# ## Phase 1 — Step 3: Categorical Data Encoding
#
# **Requirements:**
# - Check for text/categorical columns (`object`, `category`)
# - Apply encoding if needed, or explain why encoding is not required

# %%
# Write your code here

# %% [markdown]
# ## Phase 1 — Step 4: Prepare Features and Split the Data
#
# **Requirements:**
# - Separate features (`X`) and target (`y`) based on your understanding of the dataset
# - Split into training and test sets (80/20) with a fixed `random_state`
# - Apply any preprocessing your chosen approach requires (e.g. scaling) — **justify your choices** in comments
# - Print shapes of the resulting arrays

# %%
# Write your code here

# %% [markdown]
# ---
# # Phase 2: Modeling
#
# Train a model, make predictions, and evaluate performance.

# %% [markdown]
# ## Phase 2 — Step 5: Train a Model
#
# **Requirements:**
# - Based on your problem analysis, **choose an appropriate algorithm**
# - Train the model on the training set
# - Briefly explain **why** you chose this algorithm (comment or print)

# %%
# Write your code here

# %% [markdown]
# ## Phase 2 — Step 6: Predict
#
# **Requirements:**
# - Generate predictions on the test set
# - Show at least 5 sample comparisons between actual and predicted values
# - Include any extra outputs your model provides (e.g. probabilities) if applicable

# %%
# Write your code here

# %% [markdown]
# ## Phase 2 — Step 7: Visualization
#
# **Requirements:**
# - Create at least **one plot** that helps understand the data, the model, or the results
# - Use clear axis labels and a descriptive title

# %%
# Write your code here

# %% [markdown]
# ## Phase 2 — Step 8: Evaluation
#
# **Requirements:**
# - Choose **appropriate metrics** for the problem type you identified
# - Report your results clearly (table, confusion matrix, or other suitable format)
# - Briefly interpret whether the model performs well and why

# %%
# Write your code here

# %% [markdown]
# ---
# ## Submission
#
# Before submitting, make sure:
#
# 1. **Run all** completes without errors
# 2. Every code cell contains your solution (do not leave `# Write your code here`)
# 3. You stated what problem type you identified and which algorithm you chose (with justification)
# 4. Dataset path: `../Datasets/student_admission.csv`
