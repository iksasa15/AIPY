# %% [markdown]
# # مشروع: مجموعة بيانات قبول الطلاب
#
# لديك مجموعة بيانات عن طلبات الطلاب. مهمتك **استكشاف البيانات**، **تحديد نوع مشكلة تعلم الآلة**، **اختيار نهج مناسب**، وبناء **خط أنابيب كامل** من المعالجة المسبقة إلى التقييم.
#
# | العمود | الوصف |
# |--------|-------|
# | `GPA` | المعدل التراكمي |
# | `SAT` | درجة SAT |
# | `Extracurricular_Hours` | ساعات الأنشطة اللاصفية أسبوعياً |
# | `Attendance_Pct` | نسبة الحضور |
# | `Admitted` | نتيجة الطلب |
#
# **مسار البيانات:** `../Datasets/student_admission.csv`
#
# | المرحلة | الموضوع |
# |---------|--------|
# | Phase 0 | الإعداد — تثبيت واستيراد المكتبات |
# | Phase 1 | معالجة البيانات — تحميل → تنظيف → ترميز → تجهيز للنمذجة |
# | Phase 2 | النمذجة — تدريب → تنبؤ → تصور → تقييم |
#
# > **تعليمات:** أكمل كل خلية كود فارغة أدناه. نفّذ **Run all** قبل التسليم.

# %% [markdown]
# ## Phase 0 — الخطوة 1: تثبيت المكتبات
#
# **المطلوب:**
# - ثبّت المكتبات التي تحتاجها لتحليل البيانات والنمذجة
# - استخدم `-q` لإخفاء مخرجات التثبيت إذا كنت تستخدم pip

# %%
# اكتب الكود هنا

# %% [markdown]
# ## Phase 0 — الخطوة 2: استيراد المكتبات
#
# **المطلوب:**
# - استورد المكتبات التي تنوي استخدامها
# - اضبط إعدادات افتراضية مناسبة للرسوم (حجم الشكل، الثيم، random seed)
# - اطبع رسالة تأكيد عند جاهزية الاستيراد

# %%
# اكتب الكود هنا

# %% [markdown]
# ---
# # Phase 1: معالجة البيانات
#
# استكشف البيانات وجهّزها قبل النمذجة.

# %% [markdown]
# ## Phase 1 — الخطوة 1: تحميل واستكشاف البيانات
#
# **المطلوب:**
# - حمّل `../Datasets/student_admission.csv`
# - اعرض: `head()`, `info()`, `describe()`, `shape`
# - استكشف كل عمود — خاصة `Admitted` — و**اكتب استنتاجاً مختصراً** (print أو markdown) عن نوع مشكلة تعلم الآلة التي تبدو عليها

# %%
# اكتب الكود هنا

# %% [markdown]
# ## Phase 1 — الخطوة 2: تنظيف البيانات (القيم المفقودة)
#
# **المطلوب:**
# - افحص القيم المفقودة لكل عمود
# - احذف الصفوف المكررة إن وُجدت
# - عالج القيم المفقودة في الأعمدة الرقمية **عند الحاجة**

# %%
# اكتب الكود هنا

# %% [markdown]
# ## Phase 1 — الخطوة 3: ترميز البيانات الفئوية
#
# **المطلوب:**
# - افحص وجود أعمدة نصية/فئوية (`object`, `category`)
# - طبّق الترميز عند الحاجة، أو اشرح لماذا لا يلزم الترميز

# %%
# اكتب الكود هنا

# %% [markdown]
# ## Phase 1 — الخطوة 4: تجهيز الميزات وتقسيم البيانات
#
# **المطلوب:**
# - افصل الميزات (`X`) والهدف (`y`) بناءً على فهمك للمجموعة
# - قسّم إلى تدريب واختبار (80/20) مع `random_state` ثابت
# - طبّق أي معالجة مسبقة يتطلبها نهجك (مثل scaling) — **برّر اختياراتك** في التعليقات
# - اطبع أشكال المصفوفات الناتجة

# %%
# اكتب الكود هنا

# %% [markdown]
# ---
# # Phase 2: النمذجة
#
# درّب نموذجاً، تنبّأ، وقيّم الأداء.

# %% [markdown]
# ## Phase 2 — الخطوة 5: تدريب النموذج
#
# **المطلوب:**
# - بناءً على تحليلك للمشكلة، **اختر خوارزمية مناسبة**
# - درّب النموذج على مجموعة التدريب
# - اشرح **لماذا** اخترت هذه الخوارزمية (تعليق أو print)

# %%
# اكتب الكود هنا

# %% [markdown]
# ## Phase 2 — الخطوة 6: التنبؤ
#
# **المطلوب:**
# - أنشئ تنبؤات على مجموعة الاختبار
# - اعرض 5 عينات على الأقل تقارن القيم الفعلية بالمتنبأ بها
# - أضف أي مخرجات إضافية يوفرها نموذجك (مثل الاحتمالات) إن وُجدت

# %%
# اكتب الكود هنا

# %% [markdown]
# ## Phase 2 — الخطوة 7: التصور
#
# **المطلوب:**
# - أنشئ **رسمًا واحدًا على الأقل** يساعد في فهم البيانات أو النموذج أو النتائج
# - استخدم تسميات محاور وعنواناً واضحاً

# %%
# اكتب الكود هنا

# %% [markdown]
# ## Phase 2 — الخطوة 8: التقييم
#
# **المطلوب:**
# - اختر **مقاييس مناسبة** لنوع المشكلة الذي حددته
# - اعرض النتائج بوضوح (جدول، confusion matrix، أو صيغة مناسبة أخرى)
# - فسّر باختصار هل يؤدي النموذج جيداً ولماذا

# %%
# اكتب الكود هنا

# %% [markdown]
# ---
# ## التسليم
#
# قبل التسليم، تأكد من:
#
# 1. **Run all** يكتمل بدون أخطاء
# 2. كل خلية كود تحتوي على حلّك (لا تترك `# اكتب الكود هنا`)
# 3. ذكرت نوع المشكلة الذي حددته والخوارزمية التي اخترتها (مع التبرير)
# 4. مسار البيانات: `../Datasets/student_admission.csv`
